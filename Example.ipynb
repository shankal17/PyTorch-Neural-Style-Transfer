# %%
# Import custom modules
import train
import utils

# %%
# Load and show the content and style images
content_dir = 'C:/Users/17175/Documents/Pytorch-Style-Transfer/imgs/scissor_kick.jpg'
style_dir = 'C:/Users/17175/Documents/Pytorch-Style-Transfer/imgs/young_american_girl_the_dance.jpg'
content_img, style_img = utils.load_content_and_style_images(content_dir, style_dir)
utils.display_side_by_side_imgs(content_img, style_img, 'Content Image', 'Style Image')

# %%
# Do the style transfer
save_name = 'bridge_content_tree_style'
resultant_img = train.train(content_img, style_img, epochs=8001, print_every=500, save_name=save_name)
# Out:
# epoch 0: Total Loss: 1434407005061120.0
# epoch 500: Total Loss: 46271343624192.0
# epoch 1000: Total Loss: 22226080366592.0
# epoch 1500: Total Loss: 14703718825984.0
# epoch 2000: Total Loss: 11026223333376.0
# epoch 2500: Total Loss: 8545359101952.0
# epoch 3000: Total Loss: 6571867242496.0
# epoch 3500: Total Loss: 4961261322240.0
# epoch 4000: Total Loss: 3703909122048.0
# epoch 4500: Total Loss: 2768595582976.0
# epoch 5000: Total Loss: 2099632013312.0
# epoch 5500: Total Loss: 1639710588928.0
# epoch 6000: Total Loss: 1321049128960.0
# epoch 6500: Total Loss: 1092466245632.0
# epoch 7000: Total Loss: 921916342272.0
# epoch 7500: Total Loss: 784327114752.0
# epoch 8000: Total Loss: 675877093376.0
